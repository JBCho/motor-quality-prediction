# %%
import numpy as np
import pandas as pd

# %%
import os
import sys
import glob

# %%
from sklearn.model_selection import train_test_split
from catboost import CatBoostClassifier
from sklearn.metrics import accuracy_score

# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
DATA_ROOT_DIR = os.path.abspath('../data')
DATABASE_DATA_DIR = os.path.join(DATA_ROOT_DIR,'Database')
TEST_DATA_DIR = os.path.join(DATA_ROOT_DIR,'Test')
OUTPUT_DATA_DIR = os.path.join(DATA_ROOT_DIR,'Output')

files_DATABASE = glob.glob(os.path.join(DATABASE_DATA_DIR, 'Database.xlsx'))

# %%
#Test할 데이터의 기본적인 전처리를 하는 함수
def data_preprocess(df, features):
    
    #컬럼마가 다르게 NULL값 처리

    #(Char)'MAT_NAME','PRT_NAME','PROCESS','PRT_PART_NAME','CHEMICALS','DEV_STYLE_NUMBER'
    if set(['MAT_NAME','PRT_NAME','PROCESS','PRT_PART_NAME','CHEMICALS','DEV_STYLE_NUMBER']).issubset(df.columns):
        df[['MAT_NAME','PRT_NAME','PROCESS','PRT_PART_NAME','CHEMICALS','DEV_STYLE_NUMBER']]= df[['MAT_NAME','PRT_NAME','PROCESS','PRT_PART_NAME','CHEMICALS','DEV_STYLE_NUMBER']].fillna('NO_DATA')
    #(Char)'PRT_COLOR'
    if 'PRT_COLOR' in df:
        df['PRT_COLOR']=df['PRT_COLOR'].fillna('NO_COLOR')
    #(int)'GRAD','TIMES'
    if 'TIMES' in df:
        df['TIMES']=df['TIMES'].fillna(0)
    if 'GRAD' in df:
        df['GRAD']=df['GRAD'].fillna(0)
    #(int)'ROUNDS'
    if 'ROUNDS' in df:
        df['ROUNDS']=df['ROUNDS'].fillna(1)

    #전부 대문자로 통일, 빈칸 지우기
    input_features=features[:4]
    df[input_features] = df[input_features].applymap(string_preprocess)

    #더이상 사용되지 않는 PROCESS 제거
    #df=df[df.PROCESS!='POP CLEAR SCREEN PRINT']
    #df=df[df.PROCESS!='PRIMER']

    #PROCESS이름이 RULE과 다른 경우 교체
    df.loc[df['PROCESS']=='A-BOND','PROCESS']='A-BOND SCREEN PRINT'
    df.loc[df['PROCESS']=='U-BOND','PROCESS']='U-BOND SCREEN PRINT'
    df.loc[df['PROCESS']=='3D CLEAR(WG-100 12%) SCREEN PRINT','PROCESS']='3D CLEAR SCREEN PRINT'
    df.loc[df['PROCESS']=='TOP GLOSSY SCREEN PRINT','PROCESS']='TOP GLOSSY CLEAR SCREEN PRINT'
    df.loc[df['PROCESS']=='HD CLEAR SCREEN PRINT','PROCESS']='HD.CLEAR SCREEN PRINT'
    df.loc[df['PROCESS']=='3D PUFF SCREEN PRINT','PROCESS']='3D CLEAR SCREEN PRINT'
    
    #str, int 섞여있는경우 str으로 통일
    df = df.astype({'DEV_STYLE_NUMBER':'str'})
    
    #index 순서대로
    df=df.reset_index(drop=True)

    return df

# %%
def string_preprocess(s):
    s=str(s).upper()
    s_split=s.split()
    s_split = [x for x in s_split if not str(x).isdigit()]
    s=' '.join(s_split)
    return s

# %%
#Test 데이터 불러오기
filename=os.listdir(TEST_DATA_DIR)[0]
xls = pd.ExcelFile(os.path.join(TEST_DATA_DIR,filename))
df = xls.parse('Sheet1',header=0)
df.head()

#Test 데이터 전처리
features=['DEV_STYLE_NUMBER','PROCESS','PRT_PART_NAME','MAT_NAME','PRT_NAME','PRT_COLOR','CHEMICALS','GRAD','TIMES','ROUNDS']
df=data_preprocess(df, features)

# %%
#Feature는

# %%
pd.set_option('display.max_rows',None)
dup_df=df[df.duplicated(['DEV_STYLE_NUMBER','PROCESS','PRT_PART_NAME','MAT_NAME','PRT_NAME','PRT_COLOR','CHEMICALS','GRAD'],keep=False)]
dup_df[features].sort_values(by=features)
# Out:
#      DEV_STYLE_NUMBER                        PROCESS            PRT_PART_NAME  \
# 2254                              CLEAR SCREEN PRINT                 HEEL TOP
# 2313                              CLEAR SCREEN PRINT                 HEEL TOP
# 2276                              CLEAR SCREEN PRINT                    STRAP
# 2324                              CLEAR SCREEN PRINT                    STRAP
# 5101                              CLEAR SCREEN PRINT             TONGUE LABEL
# 5104                              CLEAR SCREEN PRINT             TONGUE LABEL
# 2266                              CLEAR SCREEN PRINT              TONGUE OLAY
# 2273                              CLEAR SCREEN PRINT              TONGUE OLAY
# 2316                              CLEAR SCREEN PRINT              TONGUE OLAY
# 2321                              CLEAR SCREEN PRINT              TONGUE OLAY
# 2250                              CLEAR SCREEN PRINT                     VAMP
# 2310                              CLEAR SCREEN PRINT                     VAMP
# 5102                          COLOR INK SCREEN PRINT             TONGUE LABEL
# 5105                          COLOR INK SCREEN PRINT             TONGUE LABEL
# 2317                          COLOR INK SCREEN PRINT              TONGUE OLAY
# 2319                          COLOR INK SCREEN PRINT              TONGUE OLAY
# 2267                          COLOR INK SCREEN PRINT              TONGUE OLAY
# 2271                          COLOR INK SCREEN PRINT              TONGUE OLAY
# 2257                     TOP MATT CLEAR SCREEN PRINT                 HEEL TOP
# 2315                     TOP MATT CLEAR SCREEN PRINT                 HEEL TOP
# 5103                     TOP MATT CLEAR SCREEN PRINT             TONGUE LABEL
# 5106                     TOP MATT CLEAR SCREEN PRINT             TONGUE LABEL
# 2272                     TOP MATT CLEAR SCREEN PRINT              TONGUE OLAY
# 2275                     TOP MATT CLEAR SCREEN PRINT              TONGUE OLAY
# 2320                     TOP MATT CLEAR SCREEN PRINT              TONGUE OLAY
# 2323                     TOP MATT CLEAR SCREEN PRINT              TONGUE OLAY
# 2253                     TOP MATT CLEAR SCREEN PRINT                     VAMP
# 2312                     TOP MATT CLEAR SCREEN PRINT                     VAMP
# 2268                    WHITE COLOR INK SCREEN PRINT              TONGUE OLAY
# 2270                    WHITE COLOR INK SCREEN PRINT              TONGUE OLAY
# 5050           AA0286                       CLEANING               CABLE SLIT
# 5067           AA0286                       CLEANING               CABLE SLIT
# 5084           AA0286                       CLEANING               CABLE SLIT
# 5062           AA0286                       CLEANING        QUARTER STRAP TOP
# 5079           AA0286                       CLEANING        QUARTER STRAP TOP
# 5096           AA0286                       CLEANING        QUARTER STRAP TOP
# 5051           AA0286             CLEAR SCREEN PRINT               CABLE SLIT
# 5068           AA0286             CLEAR SCREEN PRINT               CABLE SLIT
# 5085           AA0286             CLEAR SCREEN PRINT               CABLE SLIT
# 5058           AA0286             CLEAR SCREEN PRINT     QUARTER STRAP MEDIAL
# 5075           AA0286             CLEAR SCREEN PRINT     QUARTER STRAP MEDIAL
# 5092           AA0286             CLEAR SCREEN PRINT     QUARTER STRAP MEDIAL
# 5063           AA0286             CLEAR SCREEN PRINT        QUARTER STRAP TOP
# 5080           AA0286             CLEAR SCREEN PRINT        QUARTER STRAP TOP
# 5097           AA0286             CLEAR SCREEN PRINT        QUARTER STRAP TOP
# 5053           AA0286         COLOR INK SCREEN PRINT               CABLE SLIT
# 5070           AA0286         COLOR INK SCREEN PRINT               CABLE SLIT
# 5087           AA0286         COLOR INK SCREEN PRINT               CABLE SLIT
# 5065           AA0286         COLOR INK SCREEN PRINT        QUARTER STRAP TOP
# 5082           AA0286         COLOR INK SCREEN PRINT        QUARTER STRAP TOP
# 5099           AA0286         COLOR INK SCREEN PRINT        QUARTER STRAP TOP
# 5055           AA0286         LOW CLEAR SCREEN PRINT           TONGUE WEBBING
# 5072           AA0286         LOW CLEAR SCREEN PRINT           TONGUE WEBBING
# 5089           AA0286         LOW CLEAR SCREEN PRINT           TONGUE WEBBING
# 5052           AA0286           P.CLEAR SCREEN PRINT               CABLE SLIT
# 5069           AA0286           P.CLEAR SCREEN PRINT               CABLE SLIT
# 5086           AA0286           P.CLEAR SCREEN PRINT               CABLE SLIT
# 5059           AA0286           P.CLEAR SCREEN PRINT     QUARTER STRAP MEDIAL
# 5076           AA0286           P.CLEAR SCREEN PRINT     QUARTER STRAP MEDIAL
# 5093           AA0286           P.CLEAR SCREEN PRINT     QUARTER STRAP MEDIAL
# 5064           AA0286           P.CLEAR SCREEN PRINT        QUARTER STRAP TOP
# 5081           AA0286           P.CLEAR SCREEN PRINT        QUARTER STRAP TOP
# 5098           AA0286           P.CLEAR SCREEN PRINT        QUARTER STRAP TOP
# 5054           AA0286    TOP MATT CLEAR SCREEN PRINT               CABLE SLIT
# 5071           AA0286    TOP MATT CLEAR SCREEN PRINT               CABLE SLIT
# 5088           AA0286    TOP MATT CLEAR SCREEN PRINT               CABLE SLIT
# 5061           AA0286    TOP MATT CLEAR SCREEN PRINT     QUARTER STRAP MEDIAL
# 5078           AA0286    TOP MATT CLEAR SCREEN PRINT     QUARTER STRAP MEDIAL
# 5095           AA0286    TOP MATT CLEAR SCREEN PRINT     QUARTER STRAP MEDIAL
# 5066           AA0286    TOP MATT CLEAR SCREEN PRINT        QUARTER STRAP TOP
# 5083           AA0286    TOP MATT CLEAR SCREEN PRINT        QUARTER STRAP TOP
# 5100           AA0286    TOP MATT CLEAR SCREEN PRINT        QUARTER STRAP TOP
# 5057           AA0286    TOP MATT CLEAR SCREEN PRINT           TONGUE WEBBING
# 5074           AA0286    TOP MATT CLEAR SCREEN PRINT           TONGUE WEBBING
# 5091           AA0286    TOP MATT CLEAR SCREEN PRINT           TONGUE WEBBING
# 2472           AA1204                       CLEANING             TONGUE LABEL
# 2488           AA1204                       CLEANING             TONGUE LABEL
# 2468           AA1204             CLEAR SCREEN PRINT               HEEL STRAP
# 2485           AA1204             CLEAR SCREEN PRINT               HEEL STRAP
# 2465           AA1204             CLEAR SCREEN PRINT                    STRAP
# 2482           AA1204             CLEAR SCREEN PRINT                    STRAP
# 2461           AA1204             CLEAR SCREEN PRINT                 TIP OLAY
# 2479           AA1204             CLEAR SCREEN PRINT                 TIP OLAY
# 2473           AA1204             CLEAR SCREEN PRINT             TONGUE LABEL
# 2489           AA1204             CLEAR SCREEN PRINT             TONGUE LABEL
# 2471           AA1204    TOP MATT CLEAR SCREEN PRINT               HEEL STRAP
# 2487           AA1204    TOP MATT CLEAR SCREEN PRINT               HEEL STRAP
# 2464           AA1204    TOP MATT CLEAR SCREEN PRINT                 TIP OLAY
# 2481           AA1204    TOP MATT CLEAR SCREEN PRINT                 TIP OLAY
# 2478           AA1204    TOP MATT CLEAR SCREEN PRINT             TONGUE LABEL
# 2492           AA1204    TOP MATT CLEAR SCREEN PRINT             TONGUE LABEL
# 2474           AA1204   WHITE COLOR INK SCREEN PRINT             TONGUE LABEL
# 2476           AA1204   WHITE COLOR INK SCREEN PRINT             TONGUE LABEL
# 2225           CD4382           B.CLEAR SCREEN PRINT            HEEL PULL TAB
# 2237           CD4382           B.CLEAR SCREEN PRINT            HEEL PULL TAB
# 2229           CD4382           B.CLEAR SCREEN PRINT              TONGUE OLAY
# 2242           CD4382           B.CLEAR SCREEN PRINT              TONGUE OLAY
# 2232           CD4382             CLEAR SCREEN PRINT          EYESTAY LATERAL
# 2246           CD4382             CLEAR SCREEN PRINT          EYESTAY LATERAL
# 2224           CD4382             CLEAR SCREEN PRINT            HEEL PULL TAB
# 2236           CD4382             CLEAR SCREEN PRINT            HEEL PULL TAB
# 2228           CD4382             CLEAR SCREEN PRINT              TONGUE OLAY
# 2241           CD4382             CLEAR SCREEN PRINT              TONGUE OLAY
# 2234           CD4382    TOP MATT CLEAR SCREEN PRINT          EYESTAY LATERAL
# 2249           CD4382    TOP MATT CLEAR SCREEN PRINT          EYESTAY LATERAL
# 2227           CD4382    TOP MATT CLEAR SCREEN PRINT            HEEL PULL TAB
# 2240           CD4382    TOP MATT CLEAR SCREEN PRINT            HEEL PULL TAB
# 2231           CD4382    TOP MATT CLEAR SCREEN PRINT              TONGUE OLAY
# 2245           CD4382    TOP MATT CLEAR SCREEN PRINT              TONGUE OLAY
# 2348           CD4385             CLEAR SCREEN PRINT                  EYESTAY
# 2363           CD4385             CLEAR SCREEN PRINT                  EYESTAY
# 2354           CD4385             CLEAR SCREEN PRINT                   FOXING
# 2371           CD4385             CLEAR SCREEN PRINT                   FOXING
# 2351           CD4385             CLEAR SCREEN PRINT              TONGUE OLAY
# 2367           CD4385             CLEAR SCREEN PRINT              TONGUE OLAY
# 2350           CD4385    TOP MATT CLEAR SCREEN PRINT                  EYESTAY
# 2366           CD4385    TOP MATT CLEAR SCREEN PRINT                  EYESTAY
# 2356           CD4385    TOP MATT CLEAR SCREEN PRINT                   FOXING
# 2374           CD4385    TOP MATT CLEAR SCREEN PRINT                   FOXING
# 2353           CD4385    TOP MATT CLEAR SCREEN PRINT              TONGUE OLAY
# 2370           CD4385    TOP MATT CLEAR SCREEN PRINT              TONGUE OLAY
# 2446           CV0400           B.CLEAR SCREEN PRINT           SWOOSH LATERAL
# 2560           CV0400           B.CLEAR SCREEN PRINT           SWOOSH LATERAL
# 2442           CV0400           B.CLEAR SCREEN PRINT            SWOOSH MEDIAL
# 2556           CV0400           B.CLEAR SCREEN PRINT            SWOOSH MEDIAL
# 2453           CV0400           B.CLEAR SCREEN PRINT              TONGUE ULAY
# 2566           CV0400           B.CLEAR SCREEN PRINT              TONGUE ULAY
# 2449           CV0400             CLEAR SCREEN PRINT                   FOXING
# 2563           CV0400             CLEAR SCREEN PRINT                   FOXING
# 2445           CV0400             CLEAR SCREEN PRINT           SWOOSH LATERAL
# 2559           CV0400             CLEAR SCREEN PRINT           SWOOSH LATERAL
# 2441           CV0400             CLEAR SCREEN PRINT            SWOOSH MEDIAL
# 2555           CV0400             CLEAR SCREEN PRINT            SWOOSH MEDIAL
# 2457           CV0400             CLEAR SCREEN PRINT              TONGUE OLAY
# 2569           CV0400             CLEAR SCREEN PRINT              TONGUE OLAY
# 2452           CV0400    TOP MATT CLEAR SCREEN PRINT                   FOXING
# 2565           CV0400    TOP MATT CLEAR SCREEN PRINT                   FOXING
# 2460           CV0400    TOP MATT CLEAR SCREEN PRINT              TONGUE OLAY
# 2571           CV0400    TOP MATT CLEAR SCREEN PRINT              TONGUE OLAY
# 2456           CV0400    TOP MATT CLEAR SCREEN PRINT              TONGUE ULAY
# 2568           CV0400    TOP MATT CLEAR SCREEN PRINT              TONGUE ULAY
# 4966           CV1772                       CLEANING   SWOOSH-LATERAL QUARTER
# 5023           CV1772                       CLEANING   SWOOSH-LATERAL QUARTER
# 1989           DH5359           B.CLEAR SCREEN PRINT                    UPPER
# 2287           DH5359           B.CLEAR SCREEN PRINT                    UPPER
# 2004           DH5359                       CLEANING       HEEL PLATE GRAPHIC
# 2306           DH5359                       CLEANING       HEEL PLATE GRAPHIC
# 1995           DH5359             CLEAR SCREEN PRINT             EYESTAY OLAY
# 2294           DH5359             CLEAR SCREEN PRINT             EYESTAY OLAY
# 1998           DH5359             CLEAR SCREEN PRINT                   FOXING
# 2298           DH5359             CLEAR SCREEN PRINT                   FOXING
# 2001           DH5359             CLEAR SCREEN PRINT              TONGUE OLAY
# 2302           DH5359             CLEAR SCREEN PRINT              TONGUE OLAY
# 1987           DH5359             CLEAR SCREEN PRINT                    UPPER
# 1988           DH5359             CLEAR SCREEN PRINT                    UPPER
# 2285           DH5359             CLEAR SCREEN PRINT                    UPPER
# 2286           DH5359             CLEAR SCREEN PRINT                    UPPER
# 1992           DH5359          HD.CLEAR SCREEN PRINT                    UPPER
# 2291           DH5359          HD.CLEAR SCREEN PRINT                    UPPER
# 1990           DH5359          HD.CLEAR SCREEN PRINT                    UPPER
# 2288           DH5359          HD.CLEAR SCREEN PRINT                    UPPER
# 2005           DH5359          PE CLEAR SCREEN PRINT       HEEL PLATE GRAPHIC
# 2307           DH5359          PE CLEAR SCREEN PRINT       HEEL PLATE GRAPHIC
# 1997           DH5359    TOP MATT CLEAR SCREEN PRINT             EYESTAY OLAY
# 2297           DH5359    TOP MATT CLEAR SCREEN PRINT             EYESTAY OLAY
# 2000           DH5359    TOP MATT CLEAR SCREEN PRINT                   FOXING
# 2301           DH5359    TOP MATT CLEAR SCREEN PRINT                   FOXING
# 2003           DH5359    TOP MATT CLEAR SCREEN PRINT              TONGUE OLAY
# 2305           DH5359    TOP MATT CLEAR SCREEN PRINT              TONGUE OLAY
# 1994           DH5359    TOP MATT CLEAR SCREEN PRINT                    UPPER
# 2293           DH5359    TOP MATT CLEAR SCREEN PRINT                    UPPER
# 4673           DH7546   ANTI SLIP CLEAR SCREEN PRINT                  STROBEL
# 4678           DH7546   ANTI SLIP CLEAR SCREEN PRINT                  STROBEL
# 4683           DH7546   ANTI SLIP CLEAR SCREEN PRINT                  STROBEL
# 4688           DH7546   ANTI SLIP CLEAR SCREEN PRINT                  STROBEL
# 4670           DH7546         COLOR INK SCREEN PRINT                  STROBEL
# 4675           DH7546         COLOR INK SCREEN PRINT                  STROBEL
# 4680           DH7546         COLOR INK SCREEN PRINT                  STROBEL
# 4685           DH7546         COLOR INK SCREEN PRINT                  STROBEL
# 4677           DH7546         COLOR INK SCREEN PRINT                  STROBEL
# 4687           DH7546         COLOR INK SCREEN PRINT                  STROBEL
# 4672           DH7546         COLOR INK SCREEN PRINT                  STROBEL
# 4682           DH7546         COLOR INK SCREEN PRINT                  STROBEL
# 4674           DH7546         COLOR INK SCREEN PRINT                     VAMP
# 4679           DH7546         COLOR INK SCREEN PRINT                     VAMP
# 4684           DH7546         COLOR INK SCREEN PRINT                     VAMP
# 4689           DH7546         COLOR INK SCREEN PRINT                     VAMP
# 4671           DH7546         LOW CLEAR SCREEN PRINT                  STROBEL
# 4676           DH7546         LOW CLEAR SCREEN PRINT                  STROBEL
# 4681           DH7546         LOW CLEAR SCREEN PRINT                  STROBEL
# 4686           DH7546         LOW CLEAR SCREEN PRINT                  STROBEL
# 2028           DM3384            A-BOND SCREEN PRINT                SOCKLINER
# 2050           DM3384            A-BOND SCREEN PRINT                SOCKLINER
# 2021           DM3384                       CLEANING                   FOXING
# 2043           DM3384                       CLEANING                   FOXING
# 2022           DM3384             CLEAR SCREEN PRINT                   FOXING
# 2044           DM3384             CLEAR SCREEN PRINT                   FOXING
# 2026           DM3384             CLEAR SCREEN PRINT                SOCKLINER
# 2048           DM3384             CLEAR SCREEN PRINT                SOCKLINER
# 2013           DM3384             CLEAR SCREEN PRINT              TONGUE OLAY
# 2017           DM3384             CLEAR SCREEN PRINT              TONGUE OLAY
# 2035           DM3384             CLEAR SCREEN PRINT              TONGUE OLAY
# 2039           DM3384             CLEAR SCREEN PRINT              TONGUE OLAY
# 2037           DM3384         COLOR INK SCREEN PRINT              TONGUE OLAY
# 2041           DM3384         COLOR INK SCREEN PRINT              TONGUE OLAY
# 2015           DM3384         COLOR INK SCREEN PRINT              TONGUE OLAY
# 2019           DM3384         COLOR INK SCREEN PRINT              TONGUE OLAY
# 2023           DM3384         LOW CLEAR SCREEN PRINT                   FOXING
# 2045           DM3384         LOW CLEAR SCREEN PRINT                   FOXING
# 2014           DM3384         LOW CLEAR SCREEN PRINT              TONGUE OLAY
# 2018           DM3384         LOW CLEAR SCREEN PRINT              TONGUE OLAY
# 2036           DM3384         LOW CLEAR SCREEN PRINT              TONGUE OLAY
# 2040           DM3384         LOW CLEAR SCREEN PRINT              TONGUE OLAY
# 2007           DM3384         LOW CLEAR SCREEN PRINT        VAMP-QUARTER LEFT
# 2029           DM3384         LOW CLEAR SCREEN PRINT        VAMP-QUARTER LEFT
# 2010           DM3384         LOW CLEAR SCREEN PRINT       VAMP-QUARTER RIGHT
# 2032           DM3384         LOW CLEAR SCREEN PRINT       VAMP-QUARTER RIGHT
# 2025           DM3384    TOP MATT CLEAR SCREEN PRINT                   FOXING
# 2047           DM3384    TOP MATT CLEAR SCREEN PRINT                   FOXING
# 2016           DM3384    TOP MATT CLEAR SCREEN PRINT              TONGUE OLAY
# 2020           DM3384    TOP MATT CLEAR SCREEN PRINT              TONGUE OLAY
# 2038           DM3384    TOP MATT CLEAR SCREEN PRINT              TONGUE OLAY
# 2042           DM3384    TOP MATT CLEAR SCREEN PRINT              TONGUE OLAY
# 2009           DM3384    TOP MATT CLEAR SCREEN PRINT        VAMP-QUARTER LEFT
# 2031           DM3384    TOP MATT CLEAR SCREEN PRINT        VAMP-QUARTER LEFT
# 2012           DM3384    TOP MATT CLEAR SCREEN PRINT       VAMP-QUARTER RIGHT
# 2034           DM3384    TOP MATT CLEAR SCREEN PRINT       VAMP-QUARTER RIGHT
# 2069           DN2647            A-BOND SCREEN PRINT                SOCKLINER
# 2088           DN2647            A-BOND SCREEN PRINT                SOCKLINER
# 2104           DN2647            A-BOND SCREEN PRINT                SOCKLINER
# 2062           DN2647                       CLEANING                   FOXING
# 2080           DN2647                       CLEANING                   FOXING
# 2063           DN2647             CLEAR SCREEN PRINT                   FOXING
# 2081           DN2647             CLEAR SCREEN PRINT                   FOXING
# 2067           DN2647             CLEAR SCREEN PRINT                SOCKLINER
# 2086           DN2647             CLEAR SCREEN PRINT                SOCKLINER
# 2102           DN2647             CLEAR SCREEN PRINT                SOCKLINER
# 2054           DN2647             CLEAR SCREEN PRINT              TONGUE OLAY
# 2058           DN2647             CLEAR SCREEN PRINT              TONGUE OLAY
# 2070           DN2647             CLEAR SCREEN PRINT              TONGUE OLAY
# 2075           DN2647             CLEAR SCREEN PRINT              TONGUE OLAY
# 2089           DN2647             CLEAR SCREEN PRINT              TONGUE OLAY
# 2093           DN2647             CLEAR SCREEN PRINT              TONGUE OLAY
# 2073           DN2647         COLOR INK SCREEN PRINT              TONGUE OLAY
# 2078           DN2647         COLOR INK SCREEN PRINT              TONGUE OLAY
# 2091           DN2647         COLOR INK SCREEN PRINT              TONGUE OLAY
# 2095           DN2647         COLOR INK SCREEN PRINT              TONGUE OLAY
# 2056           DN2647         COLOR INK SCREEN PRINT              TONGUE OLAY
# 2060           DN2647         COLOR INK SCREEN PRINT              TONGUE OLAY
# 2064           DN2647         LOW CLEAR SCREEN PRINT                   FOXING
# 2082           DN2647         LOW CLEAR SCREEN PRINT                   FOXING
# 2055           DN2647         LOW CLEAR SCREEN PRINT              TONGUE OLAY
# 2059           DN2647         LOW CLEAR SCREEN PRINT              TONGUE OLAY
# 2071           DN2647         LOW CLEAR SCREEN PRINT              TONGUE OLAY
# 2076           DN2647         LOW CLEAR SCREEN PRINT              TONGUE OLAY
# 2090           DN2647         LOW CLEAR SCREEN PRINT              TONGUE OLAY
# 2094           DN2647         LOW CLEAR SCREEN PRINT              TONGUE OLAY
# 2066           DN2647    TOP MATT CLEAR SCREEN PRINT                   FOXING
# 2085           DN2647    TOP MATT CLEAR SCREEN PRINT                   FOXING
# 2057           DN2647    TOP MATT CLEAR SCREEN PRINT              TONGUE OLAY
# 2061           DN2647    TOP MATT CLEAR SCREEN PRINT              TONGUE OLAY
# 2074           DN2647    TOP MATT CLEAR SCREEN PRINT              TONGUE OLAY
# 2079           DN2647    TOP MATT CLEAR SCREEN PRINT              TONGUE OLAY
# 2092           DN2647    TOP MATT CLEAR SCREEN PRINT              TONGUE OLAY
# 2096           DN2647    TOP MATT CLEAR SCREEN PRINT              TONGUE OLAY
# 2072           DN2647   WHITE COLOR INK SCREEN PRINT              TONGUE OLAY
# 2077           DN2647   WHITE COLOR INK SCREEN PRINT              TONGUE OLAY
# 4870           DN3555                       CLEANING      AIRBAG LOGO LATERAL
# 4892           DN3555                       CLEANING      AIRBAG LOGO LATERAL
# 1480           DN3555                       CLEANING      AIRBAG LOGO LATERAL
# 1765           DN3555                       CLEANING      AIRBAG LOGO LATERAL
# 1939           DN3555                       CLEANING      AIRBAG LOGO LATERAL
# 3843           DN3555                       CLEANING      AIRBAG LOGO LATERAL
# 3866           DN3555                       CLEANING      AIRBAG LOGO LATERAL
# 4872           DN3555                       CLEANING       AIRBAG LOGO MEDIAL
# 4894           DN3555                       CLEANING       AIRBAG LOGO MEDIAL
# 1482           DN3555                       CLEANING       AIRBAG LOGO MEDIAL
# 1767           DN3555                       CLEANING       AIRBAG LOGO MEDIAL
# 1941           DN3555                       CLEANING       AIRBAG LOGO MEDIAL
# 3845           DN3555                       CLEANING       AIRBAG LOGO MEDIAL
# 3868           DN3555                       CLEANING       AIRBAG LOGO MEDIAL
# 1466           DN3555             CLEAR SCREEN PRINT     EYESTAY OLAY LATERAL
# 1751           DN3555             CLEAR SCREEN PRINT     EYESTAY OLAY LATERAL
# 1925           DN3555             CLEAR SCREEN PRINT     EYESTAY OLAY LATERAL
# 3829           DN3555             CLEAR SCREEN PRINT     EYESTAY OLAY LATERAL
# 3852           DN3555             CLEAR SCREEN PRINT     EYESTAY OLAY LATERAL
# 4855           DN3555             CLEAR SCREEN PRINT     EYESTAY OLAY LATERAL
# 4876           DN3555             CLEAR SCREEN PRINT     EYESTAY OLAY LATERAL
# 1469           DN3555             CLEAR SCREEN PRINT       HEEL PULL TAB OLAY
# 1754           DN3555             CLEAR SCREEN PRINT       HEEL PULL TAB OLAY
# 1928           DN3555             CLEAR SCREEN PRINT       HEEL PULL TAB OLAY
# 3832           DN3555             CLEAR SCREEN PRINT       HEEL PULL TAB OLAY
# 3855           DN3555             CLEAR SCREEN PRINT       HEEL PULL TAB OLAY
# 4858           DN3555             CLEAR SCREEN PRINT       HEEL PULL TAB OLAY
# 4879           DN3555             CLEAR SCREEN PRINT       HEEL PULL TAB OLAY
# 1472           DN3555             CLEAR SCREEN PRINT     TONGUE PULL TAB OLAY
# 1757           DN3555             CLEAR SCREEN PRINT     TONGUE PULL TAB OLAY
# 1931           DN3555             CLEAR SCREEN PRINT     TONGUE PULL TAB OLAY
# 3835           DN3555             CLEAR SCREEN PRINT     TONGUE PULL TAB OLAY
# 3858           DN3555             CLEAR SCREEN PRINT     TONGUE PULL TAB OLAY
# 4862           DN3555             CLEAR SCREEN PRINT     TONGUE PULL TAB OLAY
# 4883           DN3555             CLEAR SCREEN PRINT     TONGUE PULL TAB OLAY
# 1481           DN3555         COLOR INK SCREEN PRINT      AIRBAG LOGO LATERAL
# 3844           DN3555         COLOR INK SCREEN PRINT      AIRBAG LOGO LATERAL
# 1766           DN3555         COLOR INK SCREEN PRINT      AIRBAG LOGO LATERAL
# 1940           DN3555         COLOR INK SCREEN PRINT      AIRBAG LOGO LATERAL
# 3867           DN3555         COLOR INK SCREEN PRINT      AIRBAG LOGO LATERAL
# 1483           DN3555         COLOR INK SCREEN PRINT       AIRBAG LOGO MEDIAL
# 3846           DN3555         COLOR INK SCREEN PRINT       AIRBAG LOGO MEDIAL
# 1768           DN3555         COLOR INK SCREEN PRINT       AIRBAG LOGO MEDIAL
# 1942           DN3555         COLOR INK SCREEN PRINT       AIRBAG LOGO MEDIAL
# 3869           DN3555         COLOR INK SCREEN PRINT       AIRBAG LOGO MEDIAL
# 1752           DN3555         COLOR INK SCREEN PRINT     EYESTAY OLAY LATERAL
# 1926           DN3555         COLOR INK SCREEN PRINT     EYESTAY OLAY LATERAL
# 3853           DN3555         COLOR INK SCREEN PRINT     EYESTAY OLAY LATERAL
# 4856           DN3555         COLOR INK SCREEN PRINT     EYESTAY OLAY LATERAL
# 4877           DN3555         COLOR INK SCREEN PRINT     EYESTAY OLAY LATERAL
# 1762           DN3555         COLOR INK SCREEN PRINT      FOREFOOT PLATE LOGO
# 1936           DN3555         COLOR INK SCREEN PRINT      FOREFOOT PLATE LOGO
# 3863           DN3555         COLOR INK SCREEN PRINT      FOREFOOT PLATE LOGO
# 4867           DN3555         COLOR INK SCREEN PRINT      FOREFOOT PLATE LOGO
# 1755           DN3555         COLOR INK SCREEN PRINT       HEEL PULL TAB OLAY
# 1929           DN3555         COLOR INK SCREEN PRINT       HEEL PULL TAB OLAY
# 3856           DN3555         COLOR INK SCREEN PRINT       HEEL PULL TAB OLAY
# 4860           DN3555         COLOR INK SCREEN PRINT       HEEL PULL TAB OLAY
# 1763           DN3555         COLOR INK SCREEN PRINT       MIDFOOT PLATE LOGO
# 1937           DN3555         COLOR INK SCREEN PRINT       MIDFOOT PLATE LOGO
# 3864           DN3555         COLOR INK SCREEN PRINT       MIDFOOT PLATE LOGO
# 4868           DN3555         COLOR INK SCREEN PRINT       MIDFOOT PLATE LOGO
# 1475           DN3555         COLOR INK SCREEN PRINT        MIDSOLE HEEL LOGO
# 1760           DN3555         COLOR INK SCREEN PRINT        MIDSOLE HEEL LOGO
# 1934           DN3555         COLOR INK SCREEN PRINT        MIDSOLE HEEL LOGO
# 3838           DN3555         COLOR INK SCREEN PRINT        MIDSOLE HEEL LOGO
# 3861           DN3555         COLOR INK SCREEN PRINT        MIDSOLE HEEL LOGO
# 4865           DN3555         COLOR INK SCREEN PRINT        MIDSOLE HEEL LOGO
# 1476           DN3555         COLOR INK SCREEN PRINT     MIDSOLE LOGO LATERAL
# 3839           DN3555         COLOR INK SCREEN PRINT     MIDSOLE LOGO LATERAL
# 1761           DN3555         COLOR INK SCREEN PRINT     MIDSOLE LOGO LATERAL
# 1935           DN3555         COLOR INK SCREEN PRINT     MIDSOLE LOGO LATERAL
# 3862           DN3555         COLOR INK SCREEN PRINT     MIDSOLE LOGO LATERAL
# 4866           DN3555         COLOR INK SCREEN PRINT     MIDSOLE LOGO LATERAL
# 1479           DN3555         COLOR INK SCREEN PRINT      MIDSOLE MEDIAL LOGO
# 3842           DN3555         COLOR INK SCREEN PRINT      MIDSOLE MEDIAL LOGO
# 4891           DN3555         COLOR INK SCREEN PRINT      MIDSOLE MEDIAL LOGO
# 1764           DN3555         COLOR INK SCREEN PRINT      MIDSOLE MEDIAL LOGO
# 1938           DN3555         COLOR INK SCREEN PRINT      MIDSOLE MEDIAL LOGO
# 3865           DN3555         COLOR INK SCREEN PRINT      MIDSOLE MEDIAL LOGO
# 4869           DN3555         COLOR INK SCREEN PRINT      MIDSOLE MEDIAL LOGO
# 1750           DN3555         COLOR INK SCREEN PRINT   QUARTER LATERAL SWOOSH
# 1924           DN3555         COLOR INK SCREEN PRINT   QUARTER LATERAL SWOOSH
# 3851           DN3555         COLOR INK SCREEN PRINT   QUARTER LATERAL SWOOSH
# 4854           DN3555         COLOR INK SCREEN PRINT   QUARTER LATERAL SWOOSH
# 4875           DN3555         COLOR INK SCREEN PRINT   QUARTER LATERAL SWOOSH
# 1749           DN3555         COLOR INK SCREEN PRINT    QUARTER MEDIAL SWOOSH
# 1923           DN3555         COLOR INK SCREEN PRINT    QUARTER MEDIAL SWOOSH
# 3850           DN3555         COLOR INK SCREEN PRINT    QUARTER MEDIAL SWOOSH
# 4853           DN3555         COLOR INK SCREEN PRINT    QUARTER MEDIAL SWOOSH
# 1758           DN3555         COLOR INK SCREEN PRINT     TONGUE PULL TAB OLAY
# 1932           DN3555         COLOR INK SCREEN PRINT     TONGUE PULL TAB OLAY
# 3859           DN3555         COLOR INK SCREEN PRINT     TONGUE PULL TAB OLAY
# 4863           DN3555         COLOR INK SCREEN PRINT     TONGUE PULL TAB OLAY
# 1468           DN3555    TOP MATT CLEAR SCREEN PRINT     EYESTAY OLAY LATERAL
# 1753           DN3555    TOP MATT CLEAR SCREEN PRINT     EYESTAY OLAY LATERAL
# 1927           DN3555    TOP MATT CLEAR SCREEN PRINT     EYESTAY OLAY LATERAL
# 3831           DN3555    TOP MATT CLEAR SCREEN PRINT     EYESTAY OLAY LATERAL
# 3854           DN3555    TOP MATT CLEAR SCREEN PRINT     EYESTAY OLAY LATERAL
# 4857           DN3555    TOP MATT CLEAR SCREEN PRINT     EYESTAY OLAY LATERAL
# 4878           DN3555    TOP MATT CLEAR SCREEN PRINT     EYESTAY OLAY LATERAL
# 1471           DN3555    TOP MATT CLEAR SCREEN PRINT       HEEL PULL TAB OLAY
# 1756           DN3555    TOP MATT CLEAR SCREEN PRINT       HEEL PULL TAB OLAY
# 1930           DN3555    TOP MATT CLEAR SCREEN PRINT       HEEL PULL TAB OLAY
# 3834           DN3555    TOP MATT CLEAR SCREEN PRINT       HEEL PULL TAB OLAY
# 3857           DN3555    TOP MATT CLEAR SCREEN PRINT       HEEL PULL TAB OLAY
# 4861           DN3555    TOP MATT CLEAR SCREEN PRINT       HEEL PULL TAB OLAY
# 4882           DN3555    TOP MATT CLEAR SCREEN PRINT       HEEL PULL TAB OLAY
# 1474           DN3555    TOP MATT CLEAR SCREEN PRINT     TONGUE PULL TAB OLAY
# 1759           DN3555    TOP MATT CLEAR SCREEN PRINT     TONGUE PULL TAB OLAY
# 1933           DN3555    TOP MATT CLEAR SCREEN PRINT     TONGUE PULL TAB OLAY
# 3837           DN3555    TOP MATT CLEAR SCREEN PRINT     TONGUE PULL TAB OLAY
# 3860           DN3555    TOP MATT CLEAR SCREEN PRINT     TONGUE PULL TAB OLAY
# 4864           DN3555    TOP MATT CLEAR SCREEN PRINT     TONGUE PULL TAB OLAY
# 4886           DN3555    TOP MATT CLEAR SCREEN PRINT     TONGUE PULL TAB OLAY
# 4859           DN3555   WHITE COLOR INK SCREEN PRINT       HEEL PULL TAB OLAY
# 4880           DN3555   WHITE COLOR INK SCREEN PRINT       HEEL PULL TAB OLAY
# 4913           DN3559                       CLEANING      AIRBAG LOGO LATERAL
# 4934           DN3559                       CLEANING      AIRBAG LOGO LATERAL
# 1786           DN3559                       CLEANING      AIRBAG LOGO LATERAL
# 1919           DN3559                       CLEANING      AIRBAG LOGO LATERAL
# 2857           DN3559                       CLEANING      AIRBAG LOGO LATERAL
# 3887           DN3559                       CLEANING      AIRBAG LOGO LATERAL
# 4915           DN3559                       CLEANING       AIRBAG LOGO MEDIAL
# 4936           DN3559                       CLEANING       AIRBAG LOGO MEDIAL
# 1788           DN3559                       CLEANING       AIRBAG LOGO MEDIAL
# 1921           DN3559                       CLEANING       AIRBAG LOGO MEDIAL
# 2859           DN3559                       CLEANING       AIRBAG LOGO MEDIAL
# 3889           DN3559                       CLEANING       AIRBAG LOGO MEDIAL
# 1771           DN3559             CLEAR SCREEN PRINT     EYESTAY OLAY LATERAL
# 1904           DN3559             CLEAR SCREEN PRINT     EYESTAY OLAY LATERAL
# 3872           DN3559             CLEAR SCREEN PRINT     EYESTAY OLAY LATERAL
# 4898           DN3559             CLEAR SCREEN PRINT     EYESTAY OLAY LATERAL
# 4919           DN3559             CLEAR SCREEN PRINT     EYESTAY OLAY LATERAL
# 4901           DN3559             CLEAR SCREEN PRINT       HEEL PULL TAB OLAY
# 4922           DN3559             CLEAR SCREEN PRINT       HEEL PULL TAB OLAY
# 1774           DN3559             CLEAR SCREEN PRINT       HEEL PULL TAB OLAY
# 1907           DN3559             CLEAR SCREEN PRINT       HEEL PULL TAB OLAY
# 3875           DN3559             CLEAR SCREEN PRINT       HEEL PULL TAB OLAY
# 4905           DN3559             CLEAR SCREEN PRINT     TONGUE PULL TAB OLAY
# 4926           DN3559             CLEAR SCREEN PRINT     TONGUE PULL TAB OLAY
# 1777           DN3559             CLEAR SCREEN PRINT     TONGUE PULL TAB OLAY
# 1910           DN3559             CLEAR SCREEN PRINT     TONGUE PULL TAB OLAY
# 3878           DN3559             CLEAR SCREEN PRINT     TONGUE PULL TAB OLAY
# 4914           DN3559         COLOR INK SCREEN PRINT      AIRBAG LOGO LATERAL
# 4935           DN3559         COLOR INK SCREEN PRINT      AIRBAG LOGO LATERAL
# 1787           DN3559         COLOR INK SCREEN PRINT      AIRBAG LOGO LATERAL
# 1920           DN3559         COLOR INK SCREEN PRINT      AIRBAG LOGO LATERAL
# 3888           DN3559         COLOR INK SCREEN PRINT      AIRBAG LOGO LATERAL
# 4916           DN3559         COLOR INK SCREEN PRINT       AIRBAG LOGO MEDIAL
# 4937           DN3559         COLOR INK SCREEN PRINT       AIRBAG LOGO MEDIAL
# 1789           DN3559         COLOR INK SCREEN PRINT       AIRBAG LOGO MEDIAL
# 1922           DN3559         COLOR INK SCREEN PRINT       AIRBAG LOGO MEDIAL
# 3890           DN3559         COLOR INK SCREEN PRINT       AIRBAG LOGO MEDIAL
# 1772           DN3559         COLOR INK SCREEN PRINT     EYESTAY OLAY LATERAL
# 1905           DN3559         COLOR INK SCREEN PRINT     EYESTAY OLAY LATERAL
# 3873           DN3559         COLOR INK SCREEN PRINT     EYESTAY OLAY LATERAL
# 4899           DN3559         COLOR INK SCREEN PRINT     EYESTAY OLAY LATERAL
# 4920           DN3559         COLOR INK SCREEN PRINT     EYESTAY OLAY LATERAL
# 1784           DN3559         COLOR INK SCREEN PRINT      FOREFOOT PLATE LOGO
# 1917           DN3559         COLOR INK SCREEN PRINT      FOREFOOT PLATE LOGO
# 3885           DN3559         COLOR INK SCREEN PRINT      FOREFOOT PLATE LOGO
# 4911           DN3559         COLOR INK SCREEN PRINT      FOREFOOT PLATE LOGO
# 4932           DN3559         COLOR INK SCREEN PRINT      FOREFOOT PLATE LOGO
# 4903           DN3559         COLOR INK SCREEN PRINT       HEEL PULL TAB OLAY
# 4924           DN3559         COLOR INK SCREEN PRINT       HEEL PULL TAB OLAY
# 1775           DN3559         COLOR INK SCREEN PRINT       HEEL PULL TAB OLAY
# 1908           DN3559         COLOR INK SCREEN PRINT       HEEL PULL TAB OLAY
# 3876           DN3559         COLOR INK SCREEN PRINT       HEEL PULL TAB OLAY
# 1785           DN3559         COLOR INK SCREEN PRINT       MIDFOOT PLATE LOGO
# 1918           DN3559         COLOR INK SCREEN PRINT       MIDFOOT PLATE LOGO
# 3886           DN3559         COLOR INK SCREEN PRINT       MIDFOOT PLATE LOGO
# 4933           DN3559         COLOR INK SCREEN PRINT       MIDFOOT PLATE LOGO
# 1782           DN3559         COLOR INK SCREEN PRINT        MIDSOLE HEEL LOGO
# 1915           DN3559         COLOR INK SCREEN PRINT        MIDSOLE HEEL LOGO
# 3883           DN3559         COLOR INK SCREEN PRINT        MIDSOLE HEEL LOGO
# 4909           DN3559         COLOR INK SCREEN PRINT        MIDSOLE HEEL LOGO
# 4930           DN3559         COLOR INK SCREEN PRINT        MIDSOLE HEEL LOGO
# 1783           DN3559         COLOR INK SCREEN PRINT     MIDSOLE LOGO LATERAL
# 1916           DN3559         COLOR INK SCREEN PRINT     MIDSOLE LOGO LATERAL
# 3884           DN3559         COLOR INK SCREEN PRINT     MIDSOLE LOGO LATERAL
# 4931           DN3559         COLOR INK SCREEN PRINT     MIDSOLE LOGO LATERAL
# 1781           DN3559         COLOR INK SCREEN PRINT      MIDSOLE MEDIAL LOGO
# 1914           DN3559         COLOR INK SCREEN PRINT      MIDSOLE MEDIAL LOGO
# 3882           DN3559         COLOR INK SCREEN PRINT      MIDSOLE MEDIAL LOGO
# 1769           DN3559         COLOR INK SCREEN PRINT   QUARTER LATERAL SWOOSH
# 1902           DN3559         COLOR INK SCREEN PRINT   QUARTER LATERAL SWOOSH
# 3870           DN3559         COLOR INK SCREEN PRINT   QUARTER LATERAL SWOOSH
# 4896           DN3559         COLOR INK SCREEN PRINT   QUARTER LATERAL SWOOSH
# 1770           DN3559         COLOR INK SCREEN PRINT    QUARTER MEDIAL SWOOSH
# 1903           DN3559         COLOR INK SCREEN PRINT    QUARTER MEDIAL SWOOSH
# 3871           DN3559         COLOR INK SCREEN PRINT    QUARTER MEDIAL SWOOSH
# 4897           DN3559         COLOR INK SCREEN PRINT    QUARTER MEDIAL SWOOSH
# 4906           DN3559         COLOR INK SCREEN PRINT     TONGUE PULL TAB OLAY
# 4927           DN3559         COLOR INK SCREEN PRINT     TONGUE PULL TAB OLAY
# 1779           DN3559         COLOR INK SCREEN PRINT     TONGUE PULL TAB OLAY
# 1912           DN3559         COLOR INK SCREEN PRINT     TONGUE PULL TAB OLAY
# 3880           DN3559         COLOR INK SCREEN PRINT     TONGUE PULL TAB OLAY
# 1773           DN3559    TOP MATT CLEAR SCREEN PRINT     EYESTAY OLAY LATERAL
# 1906           DN3559    TOP MATT CLEAR SCREEN PRINT     EYESTAY OLAY LATERAL
# 2844           DN3559    TOP MATT CLEAR SCREEN PRINT     EYESTAY OLAY LATERAL
# 3874           DN3559    TOP MATT CLEAR SCREEN PRINT     EYESTAY OLAY LATERAL
# 4900           DN3559    TOP MATT CLEAR SCREEN PRINT     EYESTAY OLAY LATERAL
# 4921           DN3559    TOP MATT CLEAR SCREEN PRINT     EYESTAY OLAY LATERAL
# 2848           DN3559    TOP MATT CLEAR SCREEN PRINT       HEEL PULL TAB OLAY
# 4904           DN3559    TOP MATT CLEAR SCREEN PRINT       HEEL PULL TAB OLAY
# 4925           DN3559    TOP MATT CLEAR SCREEN PRINT       HEEL PULL TAB OLAY
# 1776           DN3559    TOP MATT CLEAR SCREEN PRINT       HEEL PULL TAB OLAY
# 1909           DN3559    TOP MATT CLEAR SCREEN PRINT       HEEL PULL TAB OLAY
# 3877           DN3559    TOP MATT CLEAR SCREEN PRINT       HEEL PULL TAB OLAY
# 2851           DN3559    TOP MATT CLEAR SCREEN PRINT     TONGUE PULL TAB OLAY
# 4907           DN3559    TOP MATT CLEAR SCREEN PRINT     TONGUE PULL TAB OLAY
# 4928           DN3559    TOP MATT CLEAR SCREEN PRINT     TONGUE PULL TAB OLAY
# 1780           DN3559    TOP MATT CLEAR SCREEN PRINT     TONGUE PULL TAB OLAY
# 1913           DN3559    TOP MATT CLEAR SCREEN PRINT     TONGUE PULL TAB OLAY
# 3881           DN3559    TOP MATT CLEAR SCREEN PRINT     TONGUE PULL TAB OLAY
# 2846           DN3559   WHITE COLOR INK SCREEN PRINT       HEEL PULL TAB OLAY
# 4902           DN3559   WHITE COLOR INK SCREEN PRINT       HEEL PULL TAB OLAY
# 4923           DN3559   WHITE COLOR INK SCREEN PRINT       HEEL PULL TAB OLAY
# 1778           DN3559   WHITE COLOR INK SCREEN PRINT     TONGUE PULL TAB OLAY
# 1911           DN3559   WHITE COLOR INK SCREEN PRINT     TONGUE PULL TAB OLAY
# 3879           DN3559   WHITE COLOR INK SCREEN PRINT     TONGUE PULL TAB OLAY
# 1894           DN4860         COLOR INK SCREEN PRINT                   FOXING
# 4744           DN4860         COLOR INK SCREEN PRINT                   FOXING
# 1895           DN4860    TOP MATT CLEAR SCREEN PRINT                   FOXING
# 4745           DN4860    TOP MATT CLEAR SCREEN PRINT                   FOXING
# 227            DN4890            A-BOND SCREEN PRINT      SOCKLINER TOP CLOTH
# 230            DN4890            A-BOND SCREEN PRINT      SOCKLINER TOP CLOTH
# 238            DN4890            A-BOND SCREEN PRINT      SOCKLINER TOP CLOTH
# 241            DN4890            A-BOND SCREEN PRINT      SOCKLINER TOP CLOTH
# 250            DN4890            A-BOND SCREEN PRINT      SOCKLINER TOP CLOTH
# 253            DN4890            A-BOND SCREEN PRINT      SOCKLINER TOP CLOTH
# 1033           DN4890            A-BOND SCREEN PRINT      SOCKLINER TOP CLOTH
# 1036           DN4890            A-BOND SCREEN PRINT      SOCKLINER TOP CLOTH
# 219            DN4890             CLEAR SCREEN PRINT            HEEL PULL TAB
# 231            DN4890             CLEAR SCREEN PRINT            HEEL PULL TAB
# 242            DN4890             CLEAR SCREEN PRINT            HEEL PULL TAB
# 4695           DN4890             CLEAR SCREEN PRINT            HEEL PULL TAB
# 4700           DN4890             CLEAR SCREEN PRINT            HEEL PULL TAB
# 4705           DN4890             CLEAR SCREEN PRINT            HEEL PULL TAB
# 1026           DN4890             CLEAR SCREEN PRINT            HEEL PULL TAB
# 4732           DN4890             CLEAR SCREEN PRINT            HEEL PULL TAB
# 4738           DN4890             CLEAR SCREEN PRINT            HEEL PULL TAB
# 225            DN4890             CLEAR SCREEN PRINT      SOCKLINER TOP CLOTH
# 228            DN4890             CLEAR SCREEN PRINT      SOCKLINER TOP CLOTH
# 236            DN4890             CLEAR SCREEN PRINT      SOCKLINER TOP CLOTH
# 239            DN4890             CLEAR SCREEN PRINT      SOCKLINER TOP CLOTH
# 248            DN4890             CLEAR SCREEN PRINT      SOCKLINER TOP CLOTH
# 251            DN4890             CLEAR SCREEN PRINT      SOCKLINER TOP CLOTH
# 1031           DN4890             CLEAR SCREEN PRINT      SOCKLINER TOP CLOTH
# 1034           DN4890             CLEAR SCREEN PRINT      SOCKLINER TOP CLOTH
# 4734           DN4890         COLOR INK SCREEN PRINT            HEEL PULL TAB
# 4741           DN4890         COLOR INK SCREEN PRINT            HEEL PULL TAB
# 1029           DN4890         COLOR INK SCREEN PRINT            HEEL PULL TAB
# 4698           DN4890         COLOR INK SCREEN PRINT            HEEL PULL TAB
# 1028           DN4890         COLOR INK SCREEN PRINT            HEEL PULL TAB
# 4697           DN4890         COLOR INK SCREEN PRINT            HEEL PULL TAB
# 229            DN4890         COLOR INK SCREEN PRINT      SOCKLINER TOP CLOTH
# 240            DN4890         COLOR INK SCREEN PRINT      SOCKLINER TOP CLOTH
# 252            DN4890         COLOR INK SCREEN PRINT      SOCKLINER TOP CLOTH
# 1035           DN4890         COLOR INK SCREEN PRINT      SOCKLINER TOP CLOTH
# 226            DN4890         COLOR INK SCREEN PRINT      SOCKLINER TOP CLOTH
# 237            DN4890         COLOR INK SCREEN PRINT      SOCKLINER TOP CLOTH
# 249            DN4890         COLOR INK SCREEN PRINT      SOCKLINER TOP CLOTH
# 1032           DN4890         COLOR INK SCREEN PRINT      SOCKLINER TOP CLOTH
# 220            DN4890         LOW CLEAR SCREEN PRINT            HEEL PULL TAB
# 232            DN4890         LOW CLEAR SCREEN PRINT            HEEL PULL TAB
# 243            DN4890         LOW CLEAR SCREEN PRINT            HEEL PULL TAB
# 1027           DN4890         LOW CLEAR SCREEN PRINT            HEEL PULL TAB
# 4696           DN4890         LOW CLEAR SCREEN PRINT            HEEL PULL TAB
# 4701           DN4890         LOW CLEAR SCREEN PRINT            HEEL PULL TAB
# 4706           DN4890         LOW CLEAR SCREEN PRINT            HEEL PULL TAB
# 4733           DN4890         LOW CLEAR SCREEN PRINT            HEEL PULL TAB
# 4739           DN4890         LOW CLEAR SCREEN PRINT            HEEL PULL TAB
# 224            DN4890    TOP MATT CLEAR SCREEN PRINT            HEEL PULL TAB
# 235            DN4890    TOP MATT CLEAR SCREEN PRINT            HEEL PULL TAB
# 247            DN4890    TOP MATT CLEAR SCREEN PRINT            HEEL PULL TAB
# 1030           DN4890    TOP MATT CLEAR SCREEN PRINT            HEEL PULL TAB
# 4699           DN4890    TOP MATT CLEAR SCREEN PRINT            HEEL PULL TAB
# 4704           DN4890    TOP MATT CLEAR SCREEN PRINT            HEEL PULL TAB
# 4709           DN4890    TOP MATT CLEAR SCREEN PRINT            HEEL PULL TAB
# 4737           DN4890    TOP MATT CLEAR SCREEN PRINT            HEEL PULL TAB
# 4742           DN4890    TOP MATT CLEAR SCREEN PRINT            HEEL PULL TAB
# 222            DN4890   WHITE COLOR INK SCREEN PRINT            HEEL PULL TAB
# 245            DN4890   WHITE COLOR INK SCREEN PRINT            HEEL PULL TAB
# 4735           DN4890   WHITE COLOR INK SCREEN PRINT            HEEL PULL TAB
# 2204           DN6948             CLEAR SCREEN PRINT                    UPPER
# 2205           DN6948             CLEAR SCREEN PRINT                    UPPER
# 4021           DO9837                       CLEANING              AIRBAG LOGO
# 4038           DO9837                       CLEANING              AIRBAG LOGO
# 3998           DO9837                       CLEANING               COLLAR TOP
# 4016           DO9837                       CLEANING               COLLAR TOP
# 4034           DO9837                       CLEANING               COLLAR TOP
# 3994           DO9837                       CLEANING   QUARTER LATERAL SWOOSH
# 4012           DO9837                       CLEANING   QUARTER LATERAL SWOOSH
# 4030           DO9837                       CLEANING   QUARTER LATERAL SWOOSH
# 3999           DO9837             CLEAR SCREEN PRINT               COLLAR TOP
# 4017           DO9837             CLEAR SCREEN PRINT               COLLAR TOP
# 4035           DO9837             CLEAR SCREEN PRINT               COLLAR TOP
# 3995           DO9837             CLEAR SCREEN PRINT   QUARTER LATERAL SWOOSH
# 4013           DO9837             CLEAR SCREEN PRINT   QUARTER LATERAL SWOOSH
# 4031           DO9837             CLEAR SCREEN PRINT   QUARTER LATERAL SWOOSH
# 3987           DO9837             CLEAR SCREEN PRINT                      TIP
# 4004           DO9837             CLEAR SCREEN PRINT                      TIP
# 4023           DO9837             CLEAR SCREEN PRINT                      TIP
# 3988           DO9837         LOW CLEAR SCREEN PRINT                      TIP
# 4005           DO9837         LOW CLEAR SCREEN PRINT                      TIP
# 4024           DO9837         LOW CLEAR SCREEN PRINT                      TIP
# 3991           DO9837         LOW CLEAR SCREEN PRINT               TONGUE TOP
# 4009           DO9837         LOW CLEAR SCREEN PRINT               TONGUE TOP
# 4027           DO9837         LOW CLEAR SCREEN PRINT               TONGUE TOP
# 4001           DO9837    TOP MATT CLEAR SCREEN PRINT               COLLAR TOP
# 4020           DO9837    TOP MATT CLEAR SCREEN PRINT               COLLAR TOP
# 4037           DO9837    TOP MATT CLEAR SCREEN PRINT               COLLAR TOP
# 3997           DO9837    TOP MATT CLEAR SCREEN PRINT   QUARTER LATERAL SWOOSH
# 4015           DO9837    TOP MATT CLEAR SCREEN PRINT   QUARTER LATERAL SWOOSH
# 4033           DO9837    TOP MATT CLEAR SCREEN PRINT   QUARTER LATERAL SWOOSH
# 3990           DO9837    TOP MATT CLEAR SCREEN PRINT                      TIP
# 4008           DO9837    TOP MATT CLEAR SCREEN PRINT                      TIP
# 4026           DO9837    TOP MATT CLEAR SCREEN PRINT                      TIP
# 3993           DO9837    TOP MATT CLEAR SCREEN PRINT               TONGUE TOP
# 4011           DO9837    TOP MATT CLEAR SCREEN PRINT               TONGUE TOP
# 4029           DO9837    TOP MATT CLEAR SCREEN PRINT               TONGUE TOP
# 1369           DP0003            A-BOND SCREEN PRINT                SOCKLINER
# ...
# 4183            WHITE      WPL#2010 series     0      4       4
# 4209            WHITE      WPL#2010 series     0      4       4
# 4234            WHITE      WPL#2010 series     0      4       4
# 4260            WHITE      WPL#2010 series     0      4       4
# 4285            WHITE      WPL#2010 series     0      4       4
# 4311            WHITE      WPL#2010 series     0      4       4
# 4336            WHITE      WPL#2010 series     0      4       4
# 4360            WHITE      WPL#2010 series     0      4       4
# 4386            WHITE      WPL#2010 series     0      4       4
# 4411            WHITE      WPL#2010 series     0      4       4
# 4436            WHITE      WPL#2010 series     0      4       4
# 4461            WHITE      WPL#2010 series     0      4       4
# 4485            WHITE      WPL#2010 series     0      4       4
# 2573         NO_COLOR      WPL#2010 series     0      4       2
# 4061         NO_COLOR      WPL#2010 series     0      4       2
# 4088         NO_COLOR      WPL#2010 series     0      4       2
# 4115         NO_COLOR      WPL#2010 series     0      4       2
# 4142         NO_COLOR      WPL#2010 series     0      4       2
# 4166         NO_COLOR      WPL#2010 series     0      4       2
# 4190         NO_COLOR      WPL#2010 series     0      4       2
# 4217         NO_COLOR      WPL#2010 series     0      4       2
# 4241         NO_COLOR      WPL#2010 series     0      4       2
# 4268         NO_COLOR      WPL#2010 series     0      4       2
# 4292         NO_COLOR      WPL#2010 series     0      4       2
# 4319         NO_COLOR      WPL#2010 series     0      4       2
# 4343         NO_COLOR      WPL#2010 series     0      4       2
# 4367         NO_COLOR      WPL#2010 series     0      4       2
# 4394         NO_COLOR      WPL#2010 series     0      4       2
# 4417         NO_COLOR      WPL#2010 series     0      4       2
# 4444         NO_COLOR      WPL#2010 series     0      4       2
# 4468         NO_COLOR      WPL#2010 series     0      4       2
# 2591         NO_COLOR      WPL#2010 series     0     12       6
# 4079         NO_COLOR      WPL#2010 series     0     12       6
# 4106         NO_COLOR      WPL#2010 series     0     12       6
# 4133         NO_COLOR      WPL#2010 series     0     12       6
# 4158         NO_COLOR      WPL#2010 series     0     12       6
# 4182         NO_COLOR      WPL#2010 series     0     12       6
# 4208         NO_COLOR      WPL#2010 series     0     12       6
# 4233         NO_COLOR      WPL#2010 series     0     12       6
# 4259         NO_COLOR      WPL#2010 series     0     12       6
# 4284         NO_COLOR      WPL#2010 series     0     12       6
# 4310         NO_COLOR      WPL#2010 series     0     12       6
# 4335         NO_COLOR      WPL#2010 series     0     12       6
# 4359         NO_COLOR      WPL#2010 series     0     12       6
# 4385         NO_COLOR      WPL#2010 series     0     12       6
# 4410         NO_COLOR      WPL#2010 series     0     12       6
# 4435         NO_COLOR      WPL#2010 series     0     12       6
# 4460         NO_COLOR      WPL#2010 series     0     12       6
# 4484         NO_COLOR      WPL#2010 series     0     12       6
# 2575         NO_COLOR      WPL#2010 series     0      2       2
# 4063         NO_COLOR      WPL#2010 series     0      2       2
# 4090         NO_COLOR      WPL#2010 series     0      2       2
# 4117         NO_COLOR      WPL#2010 series     0      2       2
# 4144         NO_COLOR      WPL#2010 series     0      2       2
# 4168         NO_COLOR      WPL#2010 series     0      2       2
# 4192         NO_COLOR      WPL#2010 series     0      2       2
# 4219         NO_COLOR      WPL#2010 series     0      2       2
# 4243         NO_COLOR      WPL#2010 series     0      2       2
# 4270         NO_COLOR      WPL#2010 series     0      2       2
# 4294         NO_COLOR      WPL#2010 series     0      2       2
# 4321         NO_COLOR      WPL#2010 series     0      2       2
# 4345         NO_COLOR      WPL#2010 series     0      2       2
# 4369         NO_COLOR      WPL#2010 series     0      2       2
# 4396         NO_COLOR      WPL#2010 series     0      2       2
# 4419         NO_COLOR      WPL#2010 series     0      2       2
# 4446         NO_COLOR      WPL#2010 series     0      2       2
# 4470         NO_COLOR      WPL#2010 series     0      2       2
# 2589         NO_COLOR      WPL#2010 series     0      2       2
# 4077         NO_COLOR      WPL#2010 series     0      2       2
# 4104         NO_COLOR      WPL#2010 series     0      2       2
# 4131         NO_COLOR      WPL#2010 series     0      2       2
# 4156         NO_COLOR      WPL#2010 series     0      2       2
# 4180         NO_COLOR      WPL#2010 series     0      2       2
# 4206         NO_COLOR      WPL#2010 series     0      2       2
# 4231         NO_COLOR      WPL#2010 series     0      2       2
# 4257         NO_COLOR      WPL#2010 series     0      2       2
# 4282         NO_COLOR      WPL#2010 series     0      2       2
# 4308         NO_COLOR      WPL#2010 series     0      2       2
# 4333         NO_COLOR      WPL#2010 series     0      2       2
# 4357         NO_COLOR      WPL#2010 series     0      2       2
# 4383         NO_COLOR      WPL#2010 series     0      2       2
# 4408         NO_COLOR      WPL#2010 series     0      2       2
# 4433         NO_COLOR      WPL#2010 series     0      2       2
# 4458         NO_COLOR      WPL#2010 series     0      2       2
# 4482         NO_COLOR      WPL#2010 series     0      2       2
# 2579         NO_COLOR      WPL#2010 series     0      2       2
# 4067         NO_COLOR      WPL#2010 series     0      2       2
# 4094         NO_COLOR      WPL#2010 series     0      2       2
# 4121         NO_COLOR      WPL#2010 series     0      2       2
# 4148         NO_COLOR      WPL#2010 series     0      2       2
# 4172         NO_COLOR      WPL#2010 series     0      2       2
# 4196         NO_COLOR      WPL#2010 series     0      2       2
# 4223         NO_COLOR      WPL#2010 series     0      2       2
# 4247         NO_COLOR      WPL#2010 series     0      2       2
# 4274         NO_COLOR      WPL#2010 series     0      2       2
# 4298         NO_COLOR      WPL#2010 series     0      2       2
# 4325         NO_COLOR      WPL#2010 series     0      2       2
# 4349         NO_COLOR      WPL#2010 series     0      2       2
# 4373         NO_COLOR      WPL#2010 series     0      2       2
# 4400         NO_COLOR      WPL#2010 series     0      2       2
# 4423         NO_COLOR      WPL#2010 series     0      2       2
# 4450         NO_COLOR      WPL#2010 series     0      2       2
# 4474         NO_COLOR      WPL#2010 series     0      2       2
# 2584         NO_COLOR      WPL#2010 series     0      2       2
# 4072         NO_COLOR      WPL#2010 series     0      2       2
# 4099         NO_COLOR      WPL#2010 series     0      2       2
# 4126         NO_COLOR      WPL#2010 series     0      2       2
# 4152         NO_COLOR      WPL#2010 series     0      2       2
# 4176         NO_COLOR      WPL#2010 series     0      2       2
# 4201         NO_COLOR      WPL#2010 series     0      2       2
# 4227         NO_COLOR      WPL#2010 series     0      2       2
# 4252         NO_COLOR      WPL#2010 series     0      2       2
# 4278         NO_COLOR      WPL#2010 series     0      2       2
# 4303         NO_COLOR      WPL#2010 series     0      2       2
# 4329         NO_COLOR      WPL#2010 series     0      2       2
# 4353         NO_COLOR      WPL#2010 series     0      2       2
# 4378         NO_COLOR      WPL#2010 series     0      2       2
# 4404         NO_COLOR      WPL#2010 series     0      2       2
# 4428         NO_COLOR      WPL#2010 series     0      2       2
# 4454         NO_COLOR      WPL#2010 series     0      2       2
# 4478         NO_COLOR      WPL#2010 series     0      2       2
# 2595         NO_COLOR      WPL#2010 series     0      2       2
# 4083         NO_COLOR      WPL#2010 series     0      2       2
# 4110         NO_COLOR      WPL#2010 series     0      2       2
# 4137         NO_COLOR      WPL#2010 series     0      2       2
# 4161         NO_COLOR      WPL#2010 series     0      2       2
# 4185         NO_COLOR      WPL#2010 series     0      2       2
# 4212         NO_COLOR      WPL#2010 series     0      2       2
# 4236         NO_COLOR      WPL#2010 series     0      2       2
# 4263         NO_COLOR      WPL#2010 series     0      2       2
# 4287         NO_COLOR      WPL#2010 series     0      2       2
# 4314         NO_COLOR      WPL#2010 series     0      2       2
# 4338         NO_COLOR      WPL#2010 series     0      2       2
# 4362         NO_COLOR      WPL#2010 series     0      2       2
# 4389         NO_COLOR      WPL#2010 series     0      2       2
# 4412         NO_COLOR      WPL#2010 series     0      2       2
# 4439         NO_COLOR      WPL#2010 series     0      2       2
# 4463         NO_COLOR      WPL#2010 series     0      2       2
# 4487         NO_COLOR      WPL#2010 series     0      2       2
# 2587         NO_COLOR      WPL#2010 series     0      2       2
# 4075         NO_COLOR      WPL#2010 series     0      2       2
# 4102         NO_COLOR      WPL#2010 series     0      2       2
# 4129         NO_COLOR      WPL#2010 series     0      2       2
# 4204         NO_COLOR      WPL#2010 series     0      2       2
# 4255         NO_COLOR      WPL#2010 series     0      2       2
# 4306         NO_COLOR      WPL#2010 series     0      2       2
# 4381         NO_COLOR      WPL#2010 series     0      2       2
# 4431         NO_COLOR      WPL#2010 series     0      2       2
# 2582         NO_COLOR      WPL#2010 series     0      2       2
# 4070         NO_COLOR      WPL#2010 series     0      2       2
# 4097         NO_COLOR      WPL#2010 series     0      2       2
# 4124         NO_COLOR      WPL#2010 series     0      2       2
# 4199         NO_COLOR      WPL#2010 series     0      2       2
# 4250         NO_COLOR      WPL#2010 series     0      2       2
# 4301         NO_COLOR      WPL#2010 series     0      2       2
# 4376         NO_COLOR      WPL#2010 series     0      2       2
# 4426         NO_COLOR      WPL#2010 series     0      2       2
# 2593         NO_COLOR      WPL#2010 series     0      2       2
# 4081         NO_COLOR      WPL#2010 series     0      2       2
# 4108         NO_COLOR      WPL#2010 series     0      2       2
# 4135         NO_COLOR      WPL#2010 series     0      2       2
# 4210         NO_COLOR      WPL#2010 series     0      2       2
# 4261         NO_COLOR      WPL#2010 series     0      2       2
# 4312         NO_COLOR      WPL#2010 series     0      2       2
# 4387         NO_COLOR      WPL#2010 series     0      2       2
# 4437         NO_COLOR      WPL#2010 series     0      2       2
# 837          NO_COLOR       MSP# 60 Series     0      2       1
# 845          NO_COLOR       MSP# 60 Series     0      2       1
# 841          NO_COLOR       MSP# 60 Series     0      2       1
# 849          NO_COLOR       MSP# 60 Series     0      2       1
# 839     METALLIC GOLD      WPL#2010 series     0      5       5
# 847     METALLIC GOLD      WPL#2010 series     0      5       5
# 843     METALLIC GOLD      WPL#2010 series     0      5       5
# 851     METALLIC GOLD      WPL#2010 series     0      5       5
# 838          NO_COLOR      WPL#2010 series     0      4       2
# 846          NO_COLOR      WPL#2010 series     0      4       2
# 842          NO_COLOR      WPL#2010 series     0      4       2
# 850          NO_COLOR      WPL#2010 series     0      4       2
# 840          NO_COLOR      WPL#2010 series     0      3       3
# 848          NO_COLOR      WPL#2010 series     0      3       3
# 844          NO_COLOR      WPL#2010 series     0      3       3
# 852          NO_COLOR      WPL#2010 series     0      3       3
# 399          NO_COLOR      WPL#2010 series     0      2       2
# 401          NO_COLOR      WPL#2010 series     0      2       2
# 1003         NO_COLOR         D-Ply S233SM     0      0       1
# 1016         NO_COLOR         D-Ply S233SM     0      0       1
# 1008         NO_COLOR       MSP# 60 Series     0      2       1
# 1021         NO_COLOR       MSP# 60 Series     0      2       1
# 1004         NO_COLOR       MSP# 60 Series     0      2       1
# 1017         NO_COLOR       MSP# 60 Series     0      2       1
# 1000         NO_COLOR       MSP# 60 Series     0      2       1
# 1013         NO_COLOR       MSP# 60 Series     0      2       1
# 1010      GHOST GREEN      WPL#2010 series     0      4       4
# 1023      GHOST GREEN      WPL#2010 series     0      4       4
# 1012     GREEN STRIKE       MSP# 60 Series     0      0       1
# 1025     GREEN STRIKE       MSP# 60 Series     0      0       1
# 1006      GHOST GREEN      WPL#2010 series     0      4       4
# 1019      GHOST GREEN      WPL#2010 series     0      4       4
# 1001            BLACK      WPL#2010 series     0      3       3
# 1014            BLACK      WPL#2010 series     0      3       3
# 1011         NO_COLOR      WPL#2010 series     0      2       2
# 1024         NO_COLOR      WPL#2010 series     0      2       2
# 1007         NO_COLOR      WPL#2010 series     0      2       2
# 1020         NO_COLOR      WPL#2010 series     0      2       2
# 1002         NO_COLOR      WPL#2010 series     0      2       2
# 1015         NO_COLOR      WPL#2010 series     0      2       2
# 1009         NO_COLOR      WPL#2010 series     0      2       2
# 1022         NO_COLOR      WPL#2010 series     0      2       2
# 1005         NO_COLOR      WPL#2010 series     0      2       2
# 1018         NO_COLOR      WPL#2010 series     0      2       2
# 1453         NO_COLOR       MSP# 60 Series     0      3       3
# 1721         NO_COLOR       MSP# 60 Series     0      3       3
# 1443         NO_COLOR         D-Ply S233SM     0      0       1
# 1711         NO_COLOR         D-Ply S233SM     0      0       1
# 1435         NO_COLOR         D-Ply S233SM     0      0       1
# 1703         NO_COLOR         D-Ply S233SM     0      0       1
# 1439         NO_COLOR         D-Ply S233SM     0      0       1
# 1707         NO_COLOR         D-Ply S233SM     0      0       1
# 1444         NO_COLOR       MSP# 60 Series     0      2       1
# 1712         NO_COLOR       MSP# 60 Series     0      2       1
# 1436         NO_COLOR       MSP# 60 Series     0      2       1
# 1704         NO_COLOR       MSP# 60 Series     0      2       1
# 1440         NO_COLOR       MSP# 60 Series     0      2       1
# 1708         NO_COLOR       MSP# 60 Series     0      2       1
# 1451         NO_COLOR      WPL#2010 series     0      2       1
# 1719         NO_COLOR      WPL#2010 series     0      2       1
# 1431         NO_COLOR       MSP# 60 Series     0      2       1
# 1699         NO_COLOR       MSP# 60 Series     0      2       1
# 1447         NO_COLOR       MSP# 60 Series     0      2       1
# 1715         NO_COLOR       MSP# 60 Series     0      2       1
# 1433  METALLIC SILVER      WPL#2010 series     0      5       5
# 1701  METALLIC SILVER      WPL#2010 series     0      5       5
# 1432         NO_COLOR      WPL#2010 series     0      4       2
# 1700         NO_COLOR      WPL#2010 series     0      4       2
# 1448         NO_COLOR      WPL#2010 series     0     12       6
# 1716         NO_COLOR      WPL#2010 series     0     12       6
# 1434         NO_COLOR      WPL#2010 series     0      2       2
# 1702         NO_COLOR      WPL#2010 series     0      2       2
# 1442         NO_COLOR      WPL#2010 series     0      3       3
# 1710         NO_COLOR      WPL#2010 series     0      3       3
# 1446         NO_COLOR      WPL#2010 series     0      2       2
# 1714         NO_COLOR      WPL#2010 series     0      2       2

# %%
dup_df[features].drop_duplicates(features,keep=False).sort_values(by=features)
# Out:
#      DEV_STYLE_NUMBER                 PROCESS      PRT_PART_NAME  \
# 3713           DX7998  COLOR INK SCREEN PRINT          SOCKLINER
# 2              DX7999     A-BOND SCREEN PRINT          SOCKLINER
# 0              DX7999      CLEAR SCREEN PRINT          SOCKLINER
# 1584           FJ5476  LOW CLEAR SCREEN PRINT  TONGUE LABEL BASE
#
#                                          MAT_NAME      PRT_NAME PRT_COLOR  \
# 3713  (PM) LINING, KNIT, BRUSHED [ RIO ], REC-RYP    수성전사지 (경성)     BLACK
# 2     (PM) LINING, KNIT, BRUSHED [ RIO ], REC-RYP    수성전사지 (경성)  NO_COLOR
# 0     (PM) LINING, KNIT, BRUSHED [ RIO ], REC-RYP    수성전사지 (경성)  NO_COLOR
# 1584                            AQUA SUEDE, 1.0MM  매시/텍스타일 (경성)  NO_COLOR
#
#             CHEMICALS  GRAD  TIMES  ROUNDS
# 3713  WPL#2010 series     0      4       4
# 2      MSP# 60 Series     0      6       3
# 0     WPL#2010 series     0      4       2
# 1584  WPL#2010 series     0     12       6

# %%
df.loc[[612,3696,3713,471,3737,3758,3779,2,469,3734,3756,3777,0,2932,2938,1584]].to_excel(os.path.join(TEST_DATA_DIR,'check.xlsx'))
